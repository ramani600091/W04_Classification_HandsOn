# %%
# %pip install import_ipynb
import pandas as pd
import numpy as np
import import_ipynb
import ClassificationWithoutGridSearch_Functions as cwgs
import warnings
warnings.filterwarnings("ignore")

# %%
filenm = "Social_Network_Ads.csv"

# %%
# Get Records for every process
ind,dep,shape =cwgs.getRows(filenm)

# %%
##SVM
vkernel='poly'
clf_report1,cm1,ypred1=cwgs.getSVMLinearClassificaiton(ind,dep,vkernel)

##DecisionTree
vkernel='entropy'
clf_report2,cm2,ypred2=cwgs.getDecisionTreeClassification(ind,dep,vkernel)

##RandomForest
vkernel='entropy'
clf_report3,cm3,ypred3=cwgs.getRandomForestClassification(ind,dep,vkernel)

##Logistic
verkel=''
clf_report4,cm4,ypred4=cwgs.getLogisticClassification(ind,dep,vkernel)

##K-Nearest_Neighbor
verkel=''
clf_report5,cm5,ypred5=cwgs.getKNearestNeighbor(ind,dep,vkernel)

##Neive Bayes (MultinomialNB)
verkel=''
clf_report6,cm6,ypred6=cwgs.getNeiveBayesMultinomialNB(ind,dep,vkernel)

##Neive Bayes (BernoulliNB)
verkel=''
clf_report7,cm7,ypred7=cwgs.getNeiveBayesBernoulliNB(ind,dep,vkernel)

##Neive Bayes (CategoricalNB)
verkel=''
clf_report8,cm8,ypred8=cwgs.getNeiveBayesCategoricalNB(ind,dep,vkernel)

##Neive Bayes (ComplementNB)
verkel=''
clf_report9,cm9,ypred9=cwgs.getNeiveBayesComplementNB(ind,dep,vkernel)

# %%
print("SVM:\n",clf_report1,
      "\nDecision Tree:\n",clf_report2,
      "\nRandom Forest:\n",clf_report3,
      "\nLogistic:\n"    ,clf_report4,
      "\nK-Nearest_Neighbor\n",clf_report5,
      "\nNeive Bayes (MultinomialNB):\n",clf_report6,
      "\nNeive Bayes (BernoulliNB):\n",clf_report7,
       "\nNeive Bayes (CategoricalNB):\n",clf_report8,
      "\nNeive Bayes (ComplementNB):\n",clf_report9)
# Out:
# SVM:
#                precision    recall  f1-score   support
#
#            0       0.72      0.96      0.82        85
#            1       0.85      0.35      0.49        49
#
#     accuracy                           0.74       134
#    macro avg       0.78      0.66      0.66       134
# weighted avg       0.77      0.74      0.70       134
#
# Decision Tree:
#                precision    recall  f1-score   support
#
#            0       0.90      0.89      0.90        85
#            1       0.82      0.84      0.83        49
#
#     accuracy                           0.87       134
#    macro avg       0.86      0.87      0.86       134
# weighted avg       0.87      0.87      0.87       134
#
# Random Forest:
#                precision    recall  f1-score   support
#
#            0       0.90      0.89      0.90        85
#            1       0.82      0.84      0.83        49
#
#     accuracy                           0.87       134
# ...
